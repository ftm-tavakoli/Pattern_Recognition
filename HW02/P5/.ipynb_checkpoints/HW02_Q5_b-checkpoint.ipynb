# %%
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import train_test_split
from itertools import combinations
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D
data = pd.read_csv('blood_test.txt')
data2=pd.read_csv('blood_test.txt')
data2['number'] = np.arange(data.shape[0])
data
# Out:
#      mcv  alkphos  sgpt  sgot  gammagt  drinks  selector
# 0     85       92    45    27       31     0.0         1
# 1     85       64    59    32       23     0.0         2
# 2     86       54    33    16       54     0.0         2
# 3     91       78    34    24       36     0.0         2
# 4     87       70    12    28       10     0.0         2
# ..   ...      ...   ...   ...      ...     ...       ...
# 340   99       75    26    24       41    12.0         1
# 341   96       69    53    43      203    12.0         2
# 342   98       77    55    35       89    15.0         1
# 343   91       68    27    26       14    16.0         1
# 344   98       99    57    45       65    20.0         1
#
# [345 rows x 7 columns]

# %%
labels = data['selector'].to_numpy()
data.drop(columns='selector', inplace=True)
train_indices = random.sample(range(0, len(data)), int(0.8 * len(data)))
test_indices  = list(set(range(0, len(data))) - set(train_indices))
df_np = data.to_numpy()
train_x = df_np[train_indices]
train_y = labels[train_indices]
test_x  = df_np[test_indices]
test_y  = labels[test_indices]
print('train_x shape:', train_x.shape)
print('train_y shape:', train_y.shape)
print('test_x shape:', test_x.shape)
print('test_y shape:', test_y.shape)
# Out:
# train_x shape: (276, 6)
# train_y shape: (276,)
# test_x shape: (69, 6)
# test_y shape: (69,)

# %%
x_train=pd.DataFrame (train_x, columns = ['mcv', 'alkphos','sgpt','sgot','gammagt','drinks'])
y_train=pd.Series(train_y,name='selector')

# %%
result = pd.concat([x_train, y_train], axis=1)

# %%
labels1 = result['selector'].to_numpy()
result.drop(columns='selector', inplace=True)
train_indices1 = random.sample(range(0, len(result)), 10)
test_indices1  = list(set(range(0, len(result))) - set(train_indices1))
df_np = result.to_numpy()
train_x1 = df_np[train_indices1]
train_y1 = labels1[train_indices1]
x_train_1=pd.DataFrame (train_x1, columns = ['mcv', 'alkphos','sgpt','sgot','gammagt','drinks'])
y_train_1=pd.Series(train_y1,name='selector')
train_indices2 = random.sample(range(0, len(result)), 50)
test_indices2  = list(set(range(0, len(result))) - set(train_indices1))
df_np = result.to_numpy()
train_x2 = df_np[train_indices2]
train_y2 = labels1[train_indices2]
x_train_2=pd.DataFrame (train_x2, columns = ['mcv', 'alkphos','sgpt','sgot','gammagt','drinks'])
y_train_2=pd.Series(train_y2,name='selector')
train_indices3 = random.sample(range(0, len(result)), 100)
test_indices3  = list(set(range(0, len(result))) - set(train_indices1))
df_np = result.to_numpy()
train_x3 = df_np[train_indices3]
train_y3 = labels1[train_indices3]
x_train_3=pd.DataFrame (train_x3, columns = ['mcv', 'alkphos','sgpt','sgot','gammagt','drinks'])
y_train_3=pd.Series(train_y3,name='selector')

# %%
def fit(X_train, y_train, classes, priors, means):
  x, y = X_train.values, y_train.values
  for i, label in enumerate(classes):
    priors[i] = y[y == label].size / y.size
    means[i] = np.mean(x[y == label], axis=0)
  covariance_matrix = covariance(x, y, classes, means)
  return means, priors, covariance_matrix

def covariance(x, y, classes, means):
  covs = [0 for i in range(len(classes))]
  cov = np.zeros(shape=(x.shape[1], x.shape[1]))
  for i, label in enumerate(classes):
    members = x[y == label]
    x_mu = members - means[i]
    cov += (x_mu).T.dot(x_mu)
    cov /= x.shape[0] 
    covs[i] = cov 
  return covs 

def probability(x, mean, prior, covariance_matrix):
  xm = x - mean
  xm_covariance = (xm.dot(np.linalg.pinv(covariance_matrix))) * xm
  xm_covariance_sum = xm_covariance.sum(axis=1)
  return -0.5 * xm_covariance_sum -(0.5) * np.log(np.linalg.det(covariance_matrix))+ np.log(prior)

def predict(X_train, classes, means, priors, covariance_matrix):
  x = X_train.values
  probabilities = np.zeros((x.shape[0], priors.size))
  for i,_ in enumerate(classes):
    probabilities[:, i] = probability(
        x, means[i]
        , priors[i]
        , covariance_matrix[i]) 
  return np.argmax(probabilities, axis=1)

def predict_proba(x):
  probabilities = np.zeros((x.shape[0], priors.size))
  for i,_ in enumerate(classes):
    probabilities[:, i] = probability(
        x, means[i]
        , priors[i]
        , covariance_matrix)
  return probabilities

# %%
def observe(X_train,y_train):
    classes = np.unique(y_train)
    classes.sort()
    means = np.zeros((classes.size, X_train.shape[1]))
    priors = np.zeros(classes.size)
    means, priors, covariance_matrix = fit(X_train, y_train, classes, priors, means)
    predicted_ys = predict(X_train, classes, means, priors, covariance_matrix)+1

    return predicted_ys

# %%
predicted_ys_1= observe(x_train_1 ,y_train_1)
error_1=0
y_train_list_1=list(y_train_1)
for i in range(len(y_train_list_1)):
    if y_train_list_1[i] != predicted_ys_1[i]:
        error_1+=1
    else:
        pass
    
error_of_mle=error_1/len(y_train_list_1)
print("MLE Error of 10 sample  is" , error_of_mle)
# Out:
# MLE Error of 10 sample  is 0.2

# %%
predicted_ys_2= observe(x_train_2 ,y_train_2)
error_2=0
y_train_list_2=list(y_train_2)
for i in range(len(y_train_list_2)):
    if y_train_list_2[i] != predicted_ys_2[i]:
        error_2+=1
    else:
        pass
    
error_of_mle=error_2/len(y_train_list_2)
print("MLE Error of 50 sample  is" , error_of_mle)
# Out:
# MLE Error of 50 sample  is 0.34

# %%
predicted_ys_3= observe(x_train_3 ,y_train_3)
error_3=0
y_train_list_3=list(y_train_3)
for i in range(len(y_train_list_3)):
    if y_train_list_3[i] != predicted_ys_3[i]:
        error_3+=1
    else:
        pass
    
error_of_mle=error_3/len(y_train_list_3)
print("MLE Error of 100 sample  is" , error_of_mle)
# Out:
# MLE Error of 100 sample  is 0.38
